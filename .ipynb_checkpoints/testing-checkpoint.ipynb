# %%
import numpy as np
import keras
from keras import *
from keras.preprocessing import image
from sklearn.metrics import confusion_matrix
from keras.applications import imagenet_utils
from keras.models import *
from keras.metrics import *
from keras.optimizers import *
from keras.layers.core import *
from keras.preprocessing.image import *
import itertools
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
mobile = keras.applications.mobilenet.MobileNet()

# %%
def prepare_image(file):
    img_path = ''
    img = image.load_img(img_path + file, target_size=(224, 224))
    img_array = image.img_to_array(img)
    img_array_expanded_dims = np.expand_dims(img_array, axis=0)
    return keras.applications.mobilenet.preprocess_input(img_array_expanded_dims)

# %%
from IPython.display import Image
Image(filename='vamp.png', width=300, height=200)

# %%
preprocessed_image = prepare_image('vamp.png')
predictions = mobile.predict(preprocessed_image)
results = imagenet_utils.decode_predictions(predictions)
results
# Out:
# Downloading data from https://storage.googleapis.com/download.tensorflow.org/data/imagenet_class_index.json
# 40960/35363 [==================================] - 0s 0us/step
# [[('n03724870', 'mask', 0.47334346),
#   ('n04548280', 'wall_clock', 0.0603178),
#   ('n02769748', 'backpack', 0.040658873),
#   ('n03595614', 'jersey', 0.039169464),
#   ('n03188531', 'diaper', 0.018881345)]]
